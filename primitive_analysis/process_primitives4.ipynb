# %%
import glob
import os
import numpy as np
import pandas as pd
import sys

from collections import OrderedDict

from matplotlib.patches import Rectangle
from matplotlib import pyplot as plt
# %matplotlib qt5

from scipy.stats import mannwhitneyu
from scipy.stats import kruskal
from scipy.stats import f_oneway
from scipy.stats import normaltest



import config 
sys.path.append('./models/v1model/')
from plotting import _get_barplot
from utils import turn_tex
turn_tex('on')

path = '/run/media/loaloa/lbb_ssd/primitives/processed2/results/'
# %matplotlib qt5

# %%
data = pd.read_csv(f'{path}/all_primitives_results_new.csv', index_col=[0,1,2])
data
# Out:
#                                          0         1         2         3  \
# exp_name     DIV design
# Cue gradient 14  480um x 12/12   -0.126280 -0.126280  0.075472 -0.406302
#                  480um x 12/11   -1.000000 -0.117216 -0.347942 -1.000000
#                  480um x 12/10   -1.000000  0.152225 -0.191854 -0.191854
#                  480um x 12/9    -0.174825 -0.161657 -0.161657 -0.161657
#                  480um x 12/8    -0.826362 -0.826362 -0.038380 -0.038380
# ...                                    ...       ...       ...       ...
# Growth speed 7   W:10um - H:24um       NaN       NaN  0.031330  0.038363
#                  W:14um - H:24um  0.480818       NaN  0.514066  0.064578
#                  W:18um - H:24um  0.322890       NaN  0.023657  0.075448
#                  W:22um - H:24um       NaN  0.631713       NaN  0.054987
#                  W:26um - H:24um  0.086956  0.146419  0.111892  0.407928
#
#                                          4         5         6         7  \
# exp_name     DIV design
# Cue gradient 14  480um x 12/12   -0.406302 -1.000000 -0.815404 -0.815404
#                  480um x 12/11    1.000000       NaN       NaN       NaN
#                  480um x 12/10   -0.191854 -1.000000 -1.000000 -0.461538
#                  480um x 12/9    -0.161657  0.340446 -1.000000 -1.000000
#                  480um x 12/8    -0.038380 -0.038380 -0.384030 -0.384030
# ...                                    ...       ...       ...       ...
# Growth speed 7   W:10um - H:24um       NaN       NaN       NaN  0.104220
#                  W:14um - H:24um       NaN       NaN  0.079284  0.251279
#                  W:18um - H:24um       NaN       NaN  0.263427  0.312020
#                  W:22um - H:24um       NaN       NaN       NaN  0.340153
#                  W:26um - H:24um       NaN       NaN       NaN  0.206522
#
#                                          8         9  ...  36  37  38  39  40  \
# exp_name     DIV design                               ...
# Cue gradient 14  480um x 12/12   -0.815404 -0.815404  ... NaN NaN NaN NaN NaN
#                  480um x 12/11         NaN       NaN  ... NaN NaN NaN NaN NaN
#                  480um x 12/10         NaN       NaN  ... NaN NaN NaN NaN NaN
#                  480um x 12/9          NaN       NaN  ... NaN NaN NaN NaN NaN
#                  480um x 12/8     0.457060  0.457060  ... NaN NaN NaN NaN NaN
# ...                                    ...       ...  ...  ..  ..  ..  ..  ..
# Growth speed 7   W:10um - H:24um  0.104220       NaN  ... NaN NaN NaN NaN NaN
#                  W:14um - H:24um  0.251279       NaN  ... NaN NaN NaN NaN NaN
#                  W:18um - H:24um  0.312020       NaN  ... NaN NaN NaN NaN NaN
#                  W:22um - H:24um  0.340153       NaN  ... NaN NaN NaN NaN NaN
#                  W:26um - H:24um  0.206522       NaN  ... NaN NaN NaN NaN NaN
#
#                                   41  42  43  44  45
# exp_name     DIV design
# Cue gradient 14  480um x 12/12   NaN NaN NaN NaN NaN
#                  480um x 12/11   NaN NaN NaN NaN NaN
#                  480um x 12/10   NaN NaN NaN NaN NaN
#                  480um x 12/9    NaN NaN NaN NaN NaN
#                  480um x 12/8    NaN NaN NaN NaN NaN
# ...                               ..  ..  ..  ..  ..
# Growth speed 7   W:10um - H:24um NaN NaN NaN NaN NaN
#                  W:14um - H:24um NaN NaN NaN NaN NaN
#                  W:18um - H:24um NaN NaN NaN NaN NaN
#                  W:22um - H:24um NaN NaN NaN NaN NaN
#                  W:26um - H:24um NaN NaN NaN NaN NaN
#
# [154 rows x 46 columns]

# %%
def compute_singles(group_values, group_levels):
    mwu_pvalues = []
    for x, x_name in zip(group_values, group_levels):
        mwu_pvals = []
        for y, y_name in zip(group_values, group_levels):
            p = mannwhitneyu(x, y).pvalue
            mwu_pvals.append(p)
            print(f'{x_name}, {y_name}: p: {p:.4f}')
        mwu_pvalues.append(mwu_pvals)
    mwu_pvalues = np.array(mwu_pvalues)

    fig, ax = plt.subplots()
    fig.subplots_adjust(bottom=.2)
    im = ax.imshow(mwu_pvalues, vmin=0, vmax=.3)
    plt.scatter(*np.where(mwu_pvalues<0.05), marker='*', color='w', s=100)
    plt.colorbar(im, orientation='vertical', label='p-value MWU test')
    plt.title(exp_name)

    lbls = [l[0] for l in group_levels]
    ax.set_yticklabels((lbls))
    ax.set_yticks(np.arange(len(lbls)))
    ax.set_xticklabels((lbls), rotation=45, ha='right')
    ax.set_xticks(np.arange(len(lbls)))



def test_kruskal_wallis(exp_data, factor, parametric=False, passed_designs=None):
    
    designs = [[d] for d in exp_data.index.unique('design')]
    if passed_designs is not None:
        designs = passed_designs
    
    groups = [exp_data.loc[d].stack().dropna() for d in designs if len(exp_data.loc[d].stack().dropna()) >2]
    group_levels = [g.name for g in groups]
    group_values = [g.values for g in groups]

    if not parametric:
        t_stat, p = kruskal(*group_values)
        which_test = 'Kruskal Wallis'
    else:
        t_stat, p = f_oneway(*group_values)
        which_test = 'ANOVA'
        var_homog = sorted([np.var(gv) for gv in group_values])
        var_homog = max(var_homog)/min(var_homog)
        normal = [normaltest(gv).pvalue if len(gv) > 7 else 0 for gv in group_values]
        normal = [p>.05 if p != 0 else 'too few samples' for p in normal]
    
    sig = '***' if p <.05 else 'N.S.'
    lbl = f'{config.SPACER}\n{factor}: n levels:{len(designs)}:\n {which_test} t={t_stat:.3f}, p={p:.4f}\n --> {sig}\n\n'
    if parametric:
        print(f'Within group normal distr: {normal}')
        print(f'Variance homogeneity (max(group_var)/min(group_var)): {var_homog}')


    print(lbl)
    
    # if passed_designs is None:
    compute_singles(group_values, designs)
    
            
exp_names = data.index.unique('exp_name')
print(exp_names)
div = 'merge'
for exp_name in exp_names:
    if div in (7,14):
        exp_dat = data.loc[(exp_name, div),:]
    elif div in ('split', 'merge'):
        exp_dat = data.loc[exp_name,:]
        if div == 'merge':
            exp_dat = exp_dat.unstack('DIV').T.reset_index(drop=True).T
    exp_name = f'{exp_name} DIV:{div}'
    print(exp_name)


    designs = None
    if exp_name.startswith('Edge transition'):
        exp_name += '_radius'
        designs = (
        ['2um, 15um','3.5um, 15um','5.5um, 15um',],
        ['2um, 25um','3.5um, 25um','5.5um, 25um',],
        ['2um, inf','3.5um, inf','5.5um, inf',], 
        ['neg. control'],)
        p = test_kruskal_wallis(exp_dat, exp_name, passed_designs=designs)
        
        exp_name += '_opening'
        designs = (
        ['5.5um, 15um','5.5um, 25um','5.5um, inf',], 
        ['3.5um, 15um','3.5um, 25um','3.5um, inf',],
        ['2um, 15um','2um, 25um','2um, inf',],
        ['neg. control'],)
        p = test_kruskal_wallis(exp_dat, exp_name, passed_designs=designs)
        
    elif exp_name.startswith('Growth speed'):
        exp_name += '_chnl_height_comparison'

        designs = [['W:0.5um - H:6um', 'W:0.75um - H:6um', 'W:1um - H:6um', 'W:1.25um - H:6um', 'W:1.5um - H:6um', 'W:1.75um - H:6um', 'W:2um - H:6um', 'W:3um - H:6um', 'W:4um - H:6um', 'W:6um - H:6um', 'W:8um - H:6um', 'W:10um - H:6um', 'W:14um - H:6um', 'W:18um - H:6um', 'W:22um - H:6um', 'W:26um - H:6um',],
    ['W:0.5um - H:24um', 'W:0.75um - H:24um', 'W:1um - H:24um', 'W:1.25um - H:24um', 'W:1.5um - H:24um', 'W:1.75um - H:24um', 'W:2um - H:24um', 'W:3um - H:24um', 'W:4um - H:24um', 'W:6um - H:24um', 'W:8um - H:24um', 'W:10um - H:24um', 'W:14um - H:24um', 'W:18um - H:24um', 'W:22um - H:24um', 'W:26um - H:24um',]]
    elif exp_name.startswith('Directionality constrain'):
        backw_designs = ['backward rescue loops',
                    'backward rescue loops angled',
                    'backward stomache',
                    'backward negative control']
        p = test_kruskal_wallis(exp_dat.loc[backw_designs], 'Backw.' + exp_name, passed_designs=None)
        forw_designs = ['forward rescue loops',
                    'forward rescue loops angled',
                    'forward stomache',
                    'forward negative control']
        p = test_kruskal_wallis(exp_dat.loc[forw_designs], 'Forw.' + exp_name, passed_designs=None)

    else:
        p = test_kruskal_wallis(exp_dat, exp_name, passed_designs=designs)
# Out:
# Index(['Cue gradient', 'Directionality constrain', 'Edge transition',
#        'Radial detachment', 'Edge attachment', 'Joining channels',
#        'Growth speed'],
#       dtype='object', name='exp_name')
# Cue gradient DIV:merge
# ========================================================
# Cue gradient DIV:merge: n levels:11:
#  Kruskal Wallis t=45.779, p=0.0000
#  --> ***
#
#
# ['480um x 12/12'], ['480um x 12/12']: p: 0.4952
# ['480um x 12/12'], ['480um x 12/11']: p: 0.3533
# ['480um x 12/12'], ['480um x 12/10']: p: 0.3507
# ['480um x 12/12'], ['480um x 12/9']: p: 0.0365
# ['480um x 12/12'], ['480um x 12/8']: p: 0.0000
# ['480um x 12/12'], ['480um x 12/7']: p: 0.0030
# ['480um x 12/12'], ['480um x 12/6']: p: 0.0006
# ['480um x 12/12'], ['480um x 12/5']: p: 0.0001
# ['480um x 12/12'], ['480um x 12/4']: p: 0.0237
# ['480um x 12/12'], ['480um x 12/3']: p: 0.1016
# ['480um x 12/12'], ['480um x 12/2']: p: 0.0003
# ['480um x 12/11'], ['480um x 12/12']: p: 0.3533
# ['480um x 12/11'], ['480um x 12/11']: p: 0.4814
# ['480um x 12/11'], ['480um x 12/10']: p: 0.3709
# ['480um x 12/11'], ['480um x 12/9']: p: 0.2479
# ['480um x 12/11'], ['480um x 12/8']: p: 0.0251
# ['480um x 12/11'], ['480um x 12/7']: p: 0.4450
# ['480um x 12/11'], ['480um x 12/6']: p: 0.2596
# ['480um x 12/11'], ['480um x 12/5']: p: 0.1336
# ['480um x 12/11'], ['480um x 12/4']: p: 0.3623
# ['480um x 12/11'], ['480um x 12/3']: p: 0.4177
# ['480um x 12/11'], ['480um x 12/2']: p: 0.1166
# ['480um x 12/10'], ['480um x 12/12']: p: 0.3507
# ['480um x 12/10'], ['480um x 12/11']: p: 0.3709
# ['480um x 12/10'], ['480um x 12/10']: p: 0.4881
# ['480um x 12/10'], ['480um x 12/9']: p: 0.0168
# ['480um x 12/10'], ['480um x 12/8']: p: 0.0001
# ['480um x 12/10'], ['480um x 12/7']: p: 0.2404
# ['480um x 12/10'], ['480um x 12/6']: p: 0.1117
# ['480um x 12/10'], ['480um x 12/5']: p: 0.0043
# ['480um x 12/10'], ['480um x 12/4']: p: 0.1372
# ['480um x 12/10'], ['480um x 12/3']: p: 0.3567
# ['480um x 12/10'], ['480um x 12/2']: p: 0.0044
# ['480um x 12/9'], ['480um x 12/12']: p: 0.0365
# ['480um x 12/9'], ['480um x 12/11']: p: 0.2479
# ['480um x 12/9'], ['480um x 12/10']: p: 0.0168
# ['480um x 12/9'], ['480um x 12/9']: p: 0.4895
# ['480um x 12/9'], ['480um x 12/8']: p: 0.0006
# ['480um x 12/9'], ['480um x 12/7']: p: 0.0648
# ['480um x 12/9'], ['480um x 12/6']: p: 0.4952
# ['480um x 12/9'], ['480um x 12/5']: p: 0.0372
# ['480um x 12/9'], ['480um x 12/4']: p: 0.3136
# ['480um x 12/9'], ['480um x 12/3']: p: 0.0120
# ['480um x 12/9'], ['480um x 12/2']: p: 0.1006
# ['480um x 12/8'], ['480um x 12/12']: p: 0.0000
# ['480um x 12/8'], ['480um x 12/11']: p: 0.0251
# ['480um x 12/8'], ['480um x 12/10']: p: 0.0001
# ['480um x 12/8'], ['480um x 12/9']: p: 0.0006
# ['480um x 12/8'], ['480um x 12/8']: p: 0.4970
# ['480um x 12/8'], ['480um x 12/7']: p: 0.0004
# ['480um x 12/8'], ['480um x 12/6']: p: 0.0004
# ['480um x 12/8'], ['480um x 12/5']: p: 0.1646
# ['480um x 12/8'], ['480um x 12/4']: p: 0.0410
# ['480um x 12/8'], ['480um x 12/3']: p: 0.0001
# ['480um x 12/8'], ['480um x 12/2']: p: 0.0469
# ['480um x 12/7'], ['480um x 12/12']: p: 0.0030
# ['480um x 12/7'], ['480um x 12/11']: p: 0.4450
# ['480um x 12/7'], ['480um x 12/10']: p: 0.2404
# ['480um x 12/7'], ['480um x 12/9']: p: 0.0648
# ['480um x 12/7'], ['480um x 12/8']: p: 0.0004
# ['480um x 12/7'], ['480um x 12/7']: p: 0.4969
# ['480um x 12/7'], ['480um x 12/6']: p: 0.2785
# ['480um x 12/7'], ['480um x 12/5']: p: 0.0314
# ['480um x 12/7'], ['480um x 12/4']: p: 0.4453
# ['480um x 12/7'], ['480um x 12/3']: p: 0.0243
# ['480um x 12/7'], ['480um x 12/2']: p: 0.0081
# ['480um x 12/6'], ['480um x 12/12']: p: 0.0006
# ['480um x 12/6'], ['480um x 12/11']: p: 0.2596
# ['480um x 12/6'], ['480um x 12/10']: p: 0.1117
# ['480um x 12/6'], ['480um x 12/9']: p: 0.4952
# ['480um x 12/6'], ['480um x 12/8']: p: 0.0004
# ['480um x 12/6'], ['480um x 12/7']: p: 0.2785
# ['480um x 12/6'], ['480um x 12/6']: p: 0.4975
# ['480um x 12/6'], ['480um x 12/5']: p: 0.0185
# ['480um x 12/6'], ['480um x 12/4']: p: 0.3176
# ['480um x 12/6'], ['480um x 12/3']: p: 0.0444
# ['480um x 12/6'], ['480um x 12/2']: p: 0.0194
# ['480um x 12/5'], ['480um x 12/12']: p: 0.0001
# ['480um x 12/5'], ['480um x 12/11']: p: 0.1336
# ['480um x 12/5'], ['480um x 12/10']: p: 0.0043
# ['480um x 12/5'], ['480um x 12/9']: p: 0.0372
# ['480um x 12/5'], ['480um x 12/8']: p: 0.1646
# ['480um x 12/5'], ['480um x 12/7']: p: 0.0314
# ['480um x 12/5'], ['480um x 12/6']: p: 0.0185
# ['480um x 12/5'], ['480um x 12/5']: p: 0.4972
# ['480um x 12/5'], ['480um x 12/4']: p: 0.0402
# ['480um x 12/5'], ['480um x 12/3']: p: 0.0024
# ['480um x 12/5'], ['480um x 12/2']: p: 0.3075
# ['480um x 12/4'], ['480um x 12/12']: p: 0.0237
# ['480um x 12/4'], ['480um x 12/11']: p: 0.3623
# ['480um x 12/4'], ['480um x 12/10']: p: 0.1372
# ['480um x 12/4'], ['480um x 12/9']: p: 0.3136
# ['480um x 12/4'], ['480um x 12/8']: p: 0.0410
# ['480um x 12/4'], ['480um x 12/7']: p: 0.4453
# ['480um x 12/4'], ['480um x 12/6']: p: 0.3176
# ['480um x 12/4'], ['480um x 12/5']: p: 0.0402
# ['480um x 12/4'], ['480um x 12/4']: p: 0.4940
# ['480um x 12/4'], ['480um x 12/3']: p: 0.1050
# ['480um x 12/4'], ['480um x 12/2']: p: 0.2512
# ['480um x 12/3'], ['480um x 12/12']: p: 0.1016
# ['480um x 12/3'], ['480um x 12/11']: p: 0.4177
# ['480um x 12/3'], ['480um x 12/10']: p: 0.3567
# ['480um x 12/3'], ['480um x 12/9']: p: 0.0120
# ['480um x 12/3'], ['480um x 12/8']: p: 0.0001
# ['480um x 12/3'], ['480um x 12/7']: p: 0.0243
# ['480um x 12/3'], ['480um x 12/6']: p: 0.0444
# ['480um x 12/3'], ['480um x 12/5']: p: 0.0024
# ['480um x 12/3'], ['480um x 12/4']: p: 0.1050
# ['480um x 12/3'], ['480um x 12/3']: p: 0.4839
# ['480um x 12/3'], ['480um x 12/2']: p: 0.0021
# ['480um x 12/2'], ['480um x 12/12']: p: 0.0003
# ['480um x 12/2'], ['480um x 12/11']: p: 0.1166
# ['480um x 12/2'], ['480um x 12/10']: p: 0.0044
# ['480um x 12/2'], ['480um x 12/9']: p: 0.1006
# ['480um x 12/2'], ['480um x 12/8']: p: 0.0469
# ['480um x 12/2'], ['480um x 12/7']: p: 0.0081
# ['480um x 12/2'], ['480um x 12/6']: p: 0.0194
# ['480um x 12/2'], ['480um x 12/5']: p: 0.3075
# ['480um x 12/2'], ['480um x 12/4']: p: 0.2512
# ['480um x 12/2'], ['480um x 12/3']: p: 0.0021
# ['480um x 12/2'], ['480um x 12/2']: p: 0.4846
# /tmp/ipykernel_49698/2392974008.py:20: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels((lbls))
# /tmp/ipykernel_49698/2392974008.py:22: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels((lbls), rotation=45, ha='right')
# Directionality constrain DIV:merge
# ========================================================
# Backw.Directionality constrain DIV:merge: n levels:4:
#  Kruskal Wallis t=7.721, p=0.0522
#  --> N.S.
#
#
# ['backward rescue loops'], ['backward rescue loops']: p: 0.4897
# ['backward rescue loops'], ['backward rescue loops angled']: p: 0.0827
# ['backward rescue loops'], ['backward stomache']: p: 0.0342
# ['backward rescue loops'], ['backward negative control']: p: 0.2620
# ['backward rescue loops angled'], ['backward rescue loops']: p: 0.0827
# ['backward rescue loops angled'], ['backward rescue loops angled']: p: 0.4885
# ['backward rescue loops angled'], ['backward stomache']: p: 0.1072
# ['backward rescue loops angled'], ['backward negative control']: p: 0.0169
# ['backward stomache'], ['backward rescue loops']: p: 0.0342
# ['backward stomache'], ['backward rescue loops angled']: p: 0.1072
# ['backward stomache'], ['backward stomache']: p: 0.4885
# ['backward stomache'], ['backward negative control']: p: 0.0263
# ['backward negative control'], ['backward rescue loops']: p: 0.2620
# ['backward negative control'], ['backward rescue loops angled']: p: 0.0169
# ['backward negative control'], ['backward stomache']: p: 0.0263
# ['backward negative control'], ['backward negative control']: p: 0.4869
# ========================================================
# Forw.Directionality constrain DIV:merge: n levels:4:
#  Kruskal Wallis t=2.558, p=0.4648
#  --> N.S.
#
#
# ['forward rescue loops'], ['forward rescue loops']: p: 0.4849
# ['forward rescue loops'], ['forward rescue loops angled']: p: 0.3665
# ['forward rescue loops'], ['forward stomache']: p: 0.0882
# ['forward rescue loops'], ['forward negative control']: p: 0.4876
# ['forward rescue loops angled'], ['forward rescue loops']: p: 0.3665
# ['forward rescue loops angled'], ['forward rescue loops angled']: p: 0.4897
# ['forward rescue loops angled'], ['forward stomache']: p: 0.1706
# ['forward rescue loops angled'], ['forward negative control']: p: 0.3408
# ['forward stomache'], ['forward rescue loops']: p: 0.0882
# ['forward stomache'], ['forward rescue loops angled']: p: 0.1706
# ['forward stomache'], ['forward stomache']: p: 0.4885
# ['forward stomache'], ['forward negative control']: p: 0.0913
# ['forward negative control'], ['forward rescue loops']: p: 0.4876
# ['forward negative control'], ['forward rescue loops angled']: p: 0.3408
# ['forward negative control'], ['forward stomache']: p: 0.0913
# ['forward negative control'], ['forward negative control']: p: 0.4897
# Edge transition DIV:merge
# ========================================================
# Edge transition DIV:merge_radius: n levels:4:
#  Kruskal Wallis t=4.185, p=0.2422
#  --> N.S.
#
#
# ['2um, 15um', '3.5um, 15um', '5.5um, 15um'], ['2um, 15um', '3.5um, 15um', '5.5um, 15um']: p: 0.4997
# ['2um, 15um', '3.5um, 15um', '5.5um, 15um'], ['2um, 25um', '3.5um, 25um', '5.5um, 25um']: p: 0.0303
# ['2um, 15um', '3.5um, 15um', '5.5um, 15um'], ['2um, inf', '3.5um, inf', '5.5um, inf']: p: 0.1457
# ['2um, 15um', '3.5um, 15um', '5.5um, 15um'], ['neg. control']: p: 0.2978
# ['2um, 25um', '3.5um, 25um', '5.5um, 25um'], ['2um, 15um', '3.5um, 15um', '5.5um, 15um']: p: 0.0303
# ['2um, 25um', '3.5um, 25um', '5.5um, 25um'], ['2um, 25um', '3.5um, 25um', '5.5um, 25um']: p: 0.4994
# ['2um, 25um', '3.5um, 25um', '5.5um, 25um'], ['2um, inf', '3.5um, inf', '5.5um, inf']: p: 0.2396
# ['2um, 25um', '3.5um, 25um', '5.5um, 25um'], ['neg. control']: p: 0.0850
# ['2um, inf', '3.5um, inf', '5.5um, inf'], ['2um, 15um', '3.5um, 15um', '5.5um, 15um']: p: 0.1457
# ['2um, inf', '3.5um, inf', '5.5um, inf'], ['2um, 25um', '3.5um, 25um', '5.5um, 25um']: p: 0.2396
# ['2um, inf', '3.5um, inf', '5.5um, inf'], ['2um, inf', '3.5um, inf', '5.5um, inf']: p: 0.4996
# ['2um, inf', '3.5um, inf', '5.5um, inf'], ['neg. control']: p: 0.1583
# ['neg. control'], ['2um, 15um', '3.5um, 15um', '5.5um, 15um']: p: 0.2978
# ['neg. control'], ['2um, 25um', '3.5um, 25um', '5.5um, 25um']: p: 0.0850
# ['neg. control'], ['2um, inf', '3.5um, inf', '5.5um, inf']: p: 0.1583
# ['neg. control'], ['neg. control']: p: 0.4986
# ========================================================
# Edge transition DIV:merge_radius_opening: n levels:4:
#  Kruskal Wallis t=8.243, p=0.0412
#  --> ***
#
#
# ['5.5um, 15um', '5.5um, 25um', '5.5um, inf'], ['5.5um, 15um', '5.5um, 25um', '5.5um, inf']: p: 0.4993
# ['5.5um, 15um', '5.5um, 25um', '5.5um, inf'], ['3.5um, 15um', '3.5um, 25um', '3.5um, inf']: p: 0.0235
# ['5.5um, 15um', '5.5um, 25um', '5.5um, inf'], ['2um, 15um', '2um, 25um', '2um, inf']: p: 0.0019
# ['5.5um, 15um', '5.5um, 25um', '5.5um, inf'], ['neg. control']: p: 0.1734
# ['3.5um, 15um', '3.5um, 25um', '3.5um, inf'], ['5.5um, 15um', '5.5um, 25um', '5.5um, inf']: p: 0.0235
# ['3.5um, 15um', '3.5um, 25um', '3.5um, inf'], ['3.5um, 15um', '3.5um, 25um', '3.5um, inf']: p: 0.4996
# ['3.5um, 15um', '3.5um, 25um', '3.5um, inf'], ['2um, 15um', '2um, 25um', '2um, inf']: p: 0.2417
# ['3.5um, 15um', '3.5um, 25um', '3.5um, inf'], ['neg. control']: p: 0.2868
# ['2um, 15um', '2um, 25um', '2um, inf'], ['5.5um, 15um', '5.5um, 25um', '5.5um, inf']: p: 0.0019
# ['2um, 15um', '2um, 25um', '2um, inf'], ['3.5um, 15um', '3.5um, 25um', '3.5um, inf']: p: 0.2417
# ['2um, 15um', '2um, 25um', '2um, inf'], ['2um, 15um', '2um, 25um', '2um, inf']: p: 0.4997
# ['2um, 15um', '2um, 25um', '2um, inf'], ['neg. control']: p: 0.1009
# ['neg. control'], ['5.5um, 15um', '5.5um, 25um', '5.5um, inf']: p: 0.1734
# ['neg. control'], ['3.5um, 15um', '3.5um, 25um', '3.5um, inf']: p: 0.2868
# ['neg. control'], ['2um, 15um', '2um, 25um', '2um, inf']: p: 0.1009
# ['neg. control'], ['neg. control']: p: 0.4986
# Radial detachment DIV:merge
# ========================================================
# Radial detachment DIV:merge: n levels:5:
#  Kruskal Wallis t=8.317, p=0.0806
#  --> N.S.
#
#
# ['5um'], ['5um']: p: 0.4990
# ['5um'], ['10um']: p: 0.0727
# ['5um'], ['15um']: p: 0.2244
# ['5um'], ['20um']: p: 0.0223
# ['5um'], ['40um']: p: 0.1405
# ['10um'], ['5um']: p: 0.0727
# ['10um'], ['10um']: p: 0.4897
# ['10um'], ['15um']: p: 0.4266
# ['10um'], ['20um']: p: 0.0104
# ['10um'], ['40um']: p: 0.0388
# ['15um'], ['5um']: p: 0.2244
# ['15um'], ['10um']: p: 0.4266
# ['15um'], ['15um']: p: 0.4945
# ['15um'], ['20um']: p: 0.0659
# ['15um'], ['40um']: p: 0.0725
# ['20um'], ['5um']: p: 0.0223
# ['20um'], ['10um']: p: 0.0104
# ['20um'], ['15um']: p: 0.0659
# ['20um'], ['20um']: p: 0.4980
# ['20um'], ['40um']: p: 0.4220
# ['40um'], ['5um']: p: 0.1405
# ['40um'], ['10um']: p: 0.0388
# ['40um'], ['15um']: p: 0.0725
# ['40um'], ['20um']: p: 0.4220
# ['40um'], ['40um']: p: 0.4971
# Edge attachment DIV:merge
# ========================================================
# Edge attachment DIV:merge: n levels:8:
#  Kruskal Wallis t=25.325, p=0.0007
#  --> ***
#
#
# ['10_hills'], ['10_hills']: p: 0.4922
# ['10_hills'], ['04_spikes']: p: 0.4226
# ['10_hills'], ['02_spikes']: p: 0.4698
# ['10_hills'], ['02_hills']: p: 0.3435
# ['10_hills'], ['10_spikes']: p: 0.0018
# ['10_hills'], ['06_spikes']: p: 0.0131
# ['10_hills'], ['04_hills']: p: 0.0891
# ['10_hills'], ['neg_control']: p: 0.3974
# ['04_spikes'], ['10_hills']: p: 0.4226
# ['04_spikes'], ['04_spikes']: p: 0.4963
# ['04_spikes'], ['02_spikes']: p: 0.1985
# ['04_spikes'], ['02_hills']: p: 0.1898
# ['04_spikes'], ['10_spikes']: p: 0.0000
# ['04_spikes'], ['06_spikes']: p: 0.0003
# ['04_spikes'], ['04_hills']: p: 0.0084
# ['04_spikes'], ['neg_control']: p: 0.4380
# ['02_spikes'], ['10_hills']: p: 0.4698
# ['02_spikes'], ['04_spikes']: p: 0.1985
# ['02_spikes'], ['02_spikes']: p: 0.4965
# ['02_spikes'], ['02_hills']: p: 0.4045
# ['02_spikes'], ['10_spikes']: p: 0.0083
# ['02_spikes'], ['06_spikes']: p: 0.0134
# ['02_spikes'], ['04_hills']: p: 0.0551
# ['02_spikes'], ['neg_control']: p: 0.3875
# ['02_hills'], ['10_hills']: p: 0.3435
# ['02_hills'], ['04_spikes']: p: 0.1898
# ['02_hills'], ['02_spikes']: p: 0.4045
# ['02_hills'], ['02_hills']: p: 0.4989
# ['02_hills'], ['10_spikes']: p: 0.0021
# ['02_hills'], ['06_spikes']: p: 0.0071
# ['02_hills'], ['04_hills']: p: 0.0449
# ['02_hills'], ['neg_control']: p: 0.3293
# ['10_spikes'], ['10_hills']: p: 0.0018
# ['10_spikes'], ['04_spikes']: p: 0.0000
# ['10_spikes'], ['02_spikes']: p: 0.0083
# ['10_spikes'], ['02_hills']: p: 0.0021
# ['10_spikes'], ['10_spikes']: p: 0.4981
# ['10_spikes'], ['06_spikes']: p: 0.3759
# ['10_spikes'], ['04_hills']: p: 0.4003
# ['10_spikes'], ['neg_control']: p: 0.0485
# ['06_spikes'], ['10_hills']: p: 0.0131
# ['06_spikes'], ['04_spikes']: p: 0.0003
# ['06_spikes'], ['02_spikes']: p: 0.0134
# ['06_spikes'], ['02_hills']: p: 0.0071
# ['06_spikes'], ['10_spikes']: p: 0.3759
# ['06_spikes'], ['06_spikes']: p: 0.4947
# ['06_spikes'], ['04_hills']: p: 0.2625
# ['06_spikes'], ['neg_control']: p: 0.0274
# ['04_hills'], ['10_hills']: p: 0.0891
# ['04_hills'], ['04_spikes']: p: 0.0084
# ['04_hills'], ['02_spikes']: p: 0.0551
# ['04_hills'], ['02_hills']: p: 0.0449
# ['04_hills'], ['10_spikes']: p: 0.4003
# ['04_hills'], ['06_spikes']: p: 0.2625
# ['04_hills'], ['04_hills']: p: 0.4945
# ['04_hills'], ['neg_control']: p: 0.2215
# ['neg_control'], ['10_hills']: p: 0.3974
# ['neg_control'], ['04_spikes']: p: 0.4380
# ['neg_control'], ['02_spikes']: p: 0.3875
# ['neg_control'], ['02_hills']: p: 0.3293
# ['neg_control'], ['10_spikes']: p: 0.0485
# ['neg_control'], ['06_spikes']: p: 0.0274
# ['neg_control'], ['04_hills']: p: 0.2215
# ['neg_control'], ['neg_control']: p: 0.4963
# Joining channels DIV:merge
# ========================================================
# Joining channels DIV:merge: n levels:8:
#  Kruskal Wallis t=31.626, p=0.0000
#  --> ***
#
#
# ['angled entry'], ['angled entry']: p: 0.4990
# ['angled entry'], ['5um opening']: p: 0.1587
# ['angled entry'], ['inlay']: p: 0.4699
# ['angled entry'], ['1.5um opening']: p: 0.0000
# ['angled entry'], ['3um opening']: p: 0.0051
# ['angled entry'], ['2x size']: p: 0.0011
# ['angled entry'], ['tangential entry']: p: 0.0003
# ['angled entry'], ['negative control']: p: 0.0042
# ['5um opening'], ['angled entry']: p: 0.1587
# ['5um opening'], ['5um opening']: p: 0.4981
# ['5um opening'], ['inlay']: p: 0.3007
# ['5um opening'], ['1.5um opening']: p: 0.0165
# ['5um opening'], ['3um opening']: p: 0.1617
# ['5um opening'], ['2x size']: p: 0.0939
# ['5um opening'], ['tangential entry']: p: 0.0067
# ['5um opening'], ['negative control']: p: 0.0843
# ['inlay'], ['angled entry']: p: 0.4699
# ['inlay'], ['5um opening']: p: 0.3007
# ['inlay'], ['inlay']: p: 0.4992
# ['inlay'], ['1.5um opening']: p: 0.0009
# ['inlay'], ['3um opening']: p: 0.0237
# ['inlay'], ['2x size']: p: 0.0183
# ['inlay'], ['tangential entry']: p: 0.0002
# ['inlay'], ['negative control']: p: 0.0104
# ['1.5um opening'], ['angled entry']: p: 0.0000
# ['1.5um opening'], ['5um opening']: p: 0.0165
# ['1.5um opening'], ['inlay']: p: 0.0009
# ['1.5um opening'], ['1.5um opening']: p: 0.4991
# ['1.5um opening'], ['3um opening']: p: 0.4480
# ['1.5um opening'], ['2x size']: p: 0.2839
# ['1.5um opening'], ['tangential entry']: p: 0.0140
# ['1.5um opening'], ['negative control']: p: 0.3965
# ['3um opening'], ['angled entry']: p: 0.0051
# ['3um opening'], ['5um opening']: p: 0.1617
# ['3um opening'], ['inlay']: p: 0.0237
# ['3um opening'], ['1.5um opening']: p: 0.4480
# ['3um opening'], ['3um opening']: p: 0.4971
# ['3um opening'], ['2x size']: p: 0.1630
# ['3um opening'], ['tangential entry']: p: 0.0854
# ['3um opening'], ['negative control']: p: 0.4722
# ['2x size'], ['angled entry']: p: 0.0011
# ['2x size'], ['5um opening']: p: 0.0939
# ['2x size'], ['inlay']: p: 0.0183
# ['2x size'], ['1.5um opening']: p: 0.2839
# ['2x size'], ['3um opening']: p: 0.1630
# ['2x size'], ['2x size']: p: 0.4929
# ['2x size'], ['tangential entry']: p: 0.1422
# ['2x size'], ['negative control']: p: 0.2940
# ['tangential entry'], ['angled entry']: p: 0.0003
# ['tangential entry'], ['5um opening']: p: 0.0067
# ['tangential entry'], ['inlay']: p: 0.0002
# ['tangential entry'], ['1.5um opening']: p: 0.0140
# ['tangential entry'], ['3um opening']: p: 0.0854
# ['tangential entry'], ['2x size']: p: 0.1422
# ['tangential entry'], ['tangential entry']: p: 0.4970
# ['tangential entry'], ['negative control']: p: 0.0770
# ['negative control'], ['angled entry']: p: 0.0042
# ['negative control'], ['5um opening']: p: 0.0843
# ['negative control'], ['inlay']: p: 0.0104
# ['negative control'], ['1.5um opening']: p: 0.3965
# ['negative control'], ['3um opening']: p: 0.4722
# ['negative control'], ['2x size']: p: 0.2940
# ['negative control'], ['tangential entry']: p: 0.0770
# ['negative control'], ['negative control']: p: 0.4981
# Growth speed DIV:merge
